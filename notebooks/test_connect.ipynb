# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd
import requests

import os
from dotenv import load_dotenv

# %%
# Connection DB
load_dotenv('../.env')

DATABASE_PASSWORD = os.environ.get("DATABASE_PASSWORD")
DATABASE_PASSWORD

connectionDB = f'mysql+pymysql://ironhack_user:{DATABASE_PASSWORD}@173.201.189.217/BiciMAD'

engineDB = create_engine(connectionDB)
inspector_db = inspect(engineDB)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/project_m1/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~/miniconda3/envs/project_m1/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/miniconda3/envs/project_m1/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# Tables DB
inspector_db.get_table_names()
# Out:
# ['bicimad_stations', 'bicipark_stations']

# %%
query_1 = '''
SELECT * FROM bicimad_stations
'''

df_1 = pd.read_sql_query(query_1, engineDB)
df_1
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_bicimad = pd.read_csv("../../datasets/bicimad_stations.csv")
df_bicimad
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_bicimad.dtypes
# Out:
# id                       int64
# name                    object
# light                    int64
# number                  object
# address                 object
# activate                 int64
# no_available             int64
# total_bases              int64
# dock_bikes               int64
# free_bases               int64
# reservations_count       int64
# geometry.type           object
# geometry.coordinates    object
# dtype: object

# %%
coordinates = df_bicimad["geometry.coordinates"][0].strip('][').split(', ')
longitud = float(coordinates[0])
latitud = float(coordinates[1])
print(f"longitud: {longitud} - latitud: {latitud}")
# Out:
# longitud: -3.7018341 - latitud: 40.4172137

# %%
def set_longitud(coordinates):
    longitud = float(coordinates.strip('][').split(', ')[0])
    return longitud

# %%
def set_latitud(coordinates):
    latitud = float(coordinates.strip('][').split(', ')[1])
    return latitud

# %%
def set_location(df):
    df[['longitud','latitud']] = df['geometry.coordinates'].str.strip('][').str.split(', ', expand=True)
    return df

# %%
df_bicimad["longitud"] = df_bicimad.apply(lambda df: set_longitud(df['geometry.coordinates']), axis=1)
df_bicimad["latitud"] = df_bicimad.apply(lambda df: set_latitud(df['geometry.coordinates']), axis=1)
df_bicimad
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_bicimad = pd.read_csv("../../datasets/bicimad_stations.csv")
df_bicimad[['longitud','latitud']] = df_bicimad['geometry.coordinates'].str.strip('][').str.split(', ', expand=True)
df_bicimad.head(3)

#df_bicimad['geometry.coordinates'].str.strip('][').str.split(', ')
# Out:
#    id                   name  light number                 address  activate  \
# 0   1  1a - Puerta del Sol A      3     1a     Puerta del Sol nº 1         1
# 1   2  1b - Puerta del Sol B      3     1b     Puerta del Sol nº 1         1
# 2   3        2 - Miguel Moya      3      2  Calle Miguel Moya nº 1         1
#
#    no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0             1           30           0           0                   0
# 1             1           30           0           0                   0
# 2             1           24           0           0                   0
#
#   geometry.type                     geometry.coordinates            longitud  \
# 0         Point                 [-3.7018341, 40.4172137]          -3.7018341
# 1         Point  [-3.701602938060457, 40.41731271011562]  -3.701602938060457
# 2         Point                 [-3.7058415, 40.4205886]          -3.7058415
#
#              latitud
# 0         40.4172137
# ...

# %%
def set_location(df):
    df[['longitud','latitud']] = df['geometry.coordinates'].str.strip('][').str.split(', ', expand=True)
    return df

# %%
df_bicimad = pd.read_csv("../../datasets/bicimad_stations.csv")

# %%
df_bicimad = set_location(df_bicimad)
df_bicimad.head(3)
# Out:
#    id                   name  light number                 address  activate  \
# 0   1  1a - Puerta del Sol A      3     1a     Puerta del Sol nº 1         1
# 1   2  1b - Puerta del Sol B      3     1b     Puerta del Sol nº 1         1
# 2   3        2 - Miguel Moya      3      2  Calle Miguel Moya nº 1         1
#
#    no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0             1           30           0           0                   0
# 1             1           30           0           0                   0
# 2             1           24           0           0                   0
#
#   geometry.type                     geometry.coordinates            longitud  \
# 0         Point                 [-3.7018341, 40.4172137]          -3.7018341
# 1         Point  [-3.701602938060457, 40.41731271011562]  -3.701602938060457
# 2         Point                 [-3.7058415, 40.4205886]          -3.7058415
#
#              latitud
# 0         40.4172137
# ...

# %%
from shapely.geometry import Point
import geopandas as gpd   # conda install -c conda-forge geopandas

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

def distance_meters(lat_start, long_start, lat_finish, long_finish):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    start = to_mercator(lat_start, long_start)
    finish = to_mercator(lat_finish, long_finish)
    return start.distance(finish)

# %%
def set_distance(df, lon_ori, lat_ori):
    df['distance'] = df.apply(lambda d: distance_meters(float(d['latitud']), float(d['longitud']), lat_ori, lon_ori), axis=1 )
    return df

# %%
df_bicimad = set_distance(df_bicimad, 40.41704834412296, -3.7055288844865233)
df_bicimad
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_bicimad[df_bicimad["distance"] == min(df_bicimad["distance"])]
# Out:
#       id           name  light number                           address  \
# 223  229  221 - Pavones      1    221  Calle Hacienda de Pavones nº 342
#
#      activate  no_available  total_bases  dock_bikes  free_bases  \
# 223         1             0           24          16           6
#
#      reservations_count geometry.type    geometry.coordinates   longitud  \
# 223                   0         Point  [-3.634587, 40.400368]  -3.634587
#
#        latitud      distance
# 223  40.400368  7.247938e+06
